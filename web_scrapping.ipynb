# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarshivam99/Language_Translator/blob/main/web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import html5lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import string
from string import digits
import re

# %%
df=pd.DataFrame(columns=["sans","eng"])
df
# Out:
# Empty DataFrame
# Columns: [sans, eng]
# Index: []

# %%
for j in range (1,68):
    url="https://www.valmiki.iitk.ac.in/sloka?field_kanda_tid=1&language=dv&field_sarga_value=%s"%(j)
    r=requests.get(url)
    html_content=r.content
    soup= BeautifulSoup(html_content,'html.parser')
    container=soup.body.contents[3].contents[1].contents[1].contents[1].contents[1].contents[3].contents[1].contents[1].contents[1].contents[3]
    for i in range(3,200,2):
        a=[]
        b=[]
        try:
          for h in container.contents[i].contents[1].stripped_strings:
            a.append(h)
          x="".join(a) 

          for h in container.contents[i].contents[5].stripped_strings:
            b.append(h)
          y="".join(b)
          df2=pd.DataFrame({"sans":[x], "eng":[y]}) 
          df=df.append(df2)
        except:
          break;   
    df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                    sans                                                eng
# 0     कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1     चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2     आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3     एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4     श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...
# ...                                                 ...                                                ...
# 1719  मम सत्या प्रतिज्ञा च वीर्यशुल्केति कौशिक।सीता ...  O Son of Kausika I announce Sita to be the 'Re...
# 1720  भवतोऽनुमते ब्रह्मन् शीघ्रं गच्छन्तु मन्त्रिण:।...  O Brahmarshi Kausika, be blessed With your con...
# ...

# %%
for j in range (1,120):
    url="https://www.valmiki.iitk.ac.in/sloka?field_kanda_tid=2&language=dv&field_sarga_value=%s"%(j)
    r=requests.get(url)
    html_content=r.content
    soup= BeautifulSoup(html_content,'html.parser')
    container=soup.body.contents[3].contents[1].contents[1].contents[1].contents[1].contents[3].contents[1].contents[1].contents[1].contents[3]
    for i in range(3,180,2):
        a=[]
        b=[]
        try:
          for h in container.contents[i].contents[1].stripped_strings:
            a.append(h)
          x="".join(a) 

          for h in container.contents[i].contents[5].stripped_strings:
            b.append(h)
          y="".join(b)
          df2=pd.DataFrame({"sans":[x], "eng":[y]}) 
          df=df.append(df2)
        except:
          break;   
    df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                    sans                                                eng
# 0     कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1     चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2     आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3     एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4     श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...
# ...                                                 ...                                                ...
# 5628  तावूचुस्ते वनचरास्तापसा धर्मचारिणः।वनस्य तस्य ...  The righteous ascetics dwelling in the forest ...
# 5629  रक्षांसि पुरुषादानि नानारूपाणि राघव।वसन्त्यस्म...  O Rama, this great forest is haunted by carniv...
# ...

# %%
for j in range (1,76):
    url="https://www.valmiki.iitk.ac.in/sloka?field_kanda_tid=3&language=dv&field_sarga_value=%s"%(j)
    r=requests.get(url)
    html_content=r.content
    soup= BeautifulSoup(html_content,'html.parser')
    container=soup.body.contents[3].contents[1].contents[1].contents[1].contents[1].contents[3].contents[1].contents[1].contents[1].contents[3]
    for i in range(3,180,2):
        a=[]
        b=[]
        try:
          for h in container.contents[i].contents[1].stripped_strings:
            a.append(h)
          x="".join(a) 

          for h in container.contents[i].contents[5].stripped_strings:
            b.append(h)
          y="".join(b)
          df2=pd.DataFrame({"sans":[x], "eng":[y]}) 
          df=df.append(df2)
        except:
          break;   
    df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                    sans                                                eng
# 0     कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1     चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2     आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3     एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4     श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...
# ...                                                 ...                                                ...
# 7795  हरेः ऋक्षरजोनाम्नः पुत्रस्तस्य महात्मनः।अध्यास...  The mighty son of Riksharaja, the great soul, ...
# 7796  सुग्रीवमभिगच्छ त्वं वानरेन्द्रं नरर्षभ।इत्युवा...  Rama said to Lakshmana, the best of men, who h...
# ...

# %%
for j in range (1,68):
    url="https://www.valmiki.iitk.ac.in/sloka?field_kanda_tid=4&language=dv&field_sarga_value=%s"%(j)
    r=requests.get(url)
    html_content=r.content
    soup= BeautifulSoup(html_content,'html.parser')
    container=soup.body.contents[3].contents[1].contents[1].contents[1].contents[1].contents[3].contents[1].contents[1].contents[1].contents[3]
    for i in range(3,180,2):
        a=[]
        b=[]
        try:
          for h in container.contents[i].contents[1].stripped_strings:
            a.append(h)
          x="".join(a) 

          for h in container.contents[i].contents[5].stripped_strings:
            b.append(h)
          y="".join(b)
          df2=pd.DataFrame({"sans":[x], "eng":[y]}) 
          df=df.append(df2)
        except:
          break;   
    df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                    sans                                                eng
# 0     कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1     चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2     आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3     एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4     श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...
# ...                                                 ...                                                ...
# 9926  मुमोच सलिलोत्पीडान्विप्रकीर्णशिलोच्चयः।।4.67.4...  The rocks of the mountain got scattered by the...
# 9927  नानागन्धर्वमिथुनैः पानसंसर्गकर्कशैः।।4.67.46।।...  Shaken by the rude shock, couples of intoxicat...
# ...

# %%
for j in range (1,69):
    url="https://www.valmiki.iitk.ac.in/sloka?field_kanda_tid=5&language=dv&field_sarga_value=%s"%(j)
    r=requests.get(url)
    html_content=r.content
    soup= BeautifulSoup(html_content,'html.parser')
    container=soup.body.contents[3].contents[1].contents[1].contents[1].contents[1].contents[3].contents[1].contents[1].contents[1].contents[3]
    for i in range(3,180,2):
        a=[]
        b=[]
        try:
          for h in container.contents[i].contents[1].stripped_strings:
            a.append(h)
          x="".join(a) 

          for h in container.contents[i].contents[5].stripped_strings:
            b.append(h)
          y="".join(b)
          df2=pd.DataFrame({"sans":[x], "eng":[y]}) 
          df=df.append(df2)
        except:
          break;   
    df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                     sans                                                eng
# 0      कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1      चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2      आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3      एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4      श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...
# ...                                                  ...                                                ...
# 12230  मम पृष्ठगतौ तौ च चन्द्रसूर्याविवोदितौ।त्वत्सका...  'O noble lady the lions among men, Rama and La...
# 12231  अरिघ्नं सिंहसङ्काशं क्षिप्रं द्रक्ष्यसि राघवम्...  'You will see the lionlike Rama, a slayer of e...
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#                                                     sans                                                eng
# 0      कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1      चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2      आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3      एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4      श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...
# ...                                                  ...                                                ...
# 12230  मम पृष्ठगतौ तौ च चन्द्रसूर्याविवोदितौ।त्वत्सका...  'O noble lady the lions among men, Rama and La...
# 12231  अरिघ्नं सिंहसङ्काशं क्षिप्रं द्रक्ष्यसि राघवम्...  'You will see the lionlike Rama, a slayer of e...
# ...

# %%
df2=df
df2=df2.reset_index(drop=True)
df2.head()
# Out:
#                                                 sans                                                eng
# 0  कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  "Who in this world lives today endowed with ex...
# 1  चारित्रेण च को युक्तस्सर्वभूतेषु को हित: ।विद्...  Who is that one gifted with good conduct, give...
# 2  आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक: ।कस्य...  Who (among men) is selfrestrained? Who has con...
# 3  एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे ।महर्ष...  O Maharshi, I intend to hear about such a man ...
# 4  श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच: ...  Invited by Valmiki to take his seat Narada, kn...

# %%
def text_preprocessing(lines):
  lines=lines.apply(lambda x: x.lower())
  lines=lines.apply(lambda x: re.sub("'", '', x))
  exclude = set(string.punctuation) # Set of all special characters
  lines=lines.apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
  remove_digits = str.maketrans('', '', digits)
  lines=lines.apply(lambda x: x.translate(remove_digits))
  lines = lines.apply(lambda x: re.sub("[२३०८१५७९४६।]", "", x))
  lines=lines.apply(lambda x: x.strip())
  lines=lines.apply(lambda x: re.sub(" +", " ", x))
  return lines

# %%
df2.eng=text_preprocessing(df2.eng)
df2.sans=text_preprocessing(df2.sans)
df2.head()
# Out:
#                                                 sans                                                eng
# 0  कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  who in this world lives today endowed with exc...
# 1  चारित्रेण च को युक्तस्सर्वभूतेषु को हित विद्वा...  who is that one gifted with good conduct given...
# 2  आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक कस्य ब...  who among men is selfrestrained who has conque...
# 3  एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे महर्षे...  o maharshi i intend to hear about such a man w...
# 4  श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच श...  invited by valmiki to take his seat narada kno...

# %%
len_list_sans=[]
for l in df2.sans:
    len_list_sans.append(len(l.split(' ')))
max_length_scr = np.max(len_list_sans)
max_length_scr
# Out:
# 56

# %%
len_list_eng=[]
for l in df2.eng:
    len_list_eng.append(len(l.split(' ')))
max_length_tar = np.max(len_list_eng)
max_length_tar
# Out:
# 227

# %%
l=df2
l["sans_len"]=len_list_sans
l["eng_len"]=len_list_eng
l
# Out:
#                                                     sans  ... eng_len
# 0      कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  ...      19
# 1      चारित्रेण च को युक्तस्सर्वभूतेषु को हित विद्वा...  ...      39
# 2      आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक कस्य ब...  ...      34
# 3      एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे महर्षे...  ...      21
# 4      श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच श...  ...      25
# ...                                                  ...  ...     ...
# 12230  मम पृष्ठगतौ तौ च चन्द्रसूर्याविवोदितौत्वत्सकाश...  ...      23
# 12231  अरिघ्नं सिंहसङ्काशं क्षिप्रं द्रक्ष्यसि राघवम्...  ...      24
# 12232  नखदंष्ट्रायुधान् वीरान् सिंहशार्दूलविक्रमान्वा...  ...      27
# 12233  निवृत्तवनवासं च त्वया सार्धमरिन्दमम्अभिषिक्तमय...  ...      26
# 12234  ततो मया वाग्भिरदीनभाषिणा शिवाभिरिष्टाभिरभिप्रस...  ...      54
#
# [12235 rows x 4 columns]

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
l['sans_len'].mean()
print("\n")
l['eng_len'].mean()
# Out:
# 8.536575398447079
# 25.940498569677157

# %%
l["dif"]=l['eng_len']/l['sans_len']
l
# Out:
#                                                     sans  ...       dif
# 0      कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  ...  2.375000
# 1      चारित्रेण च को युक्तस्सर्वभूतेषु को हित विद्वा...  ...  4.333333
# 2      आत्मवान्को जितक्रोधो द्युतिमान्कोऽनसूयक कस्य ब...  ...  4.250000
# 3      एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे महर्षे...  ...  1.909091
# 4      श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच श...  ...  3.125000
# ...                                                  ...  ...       ...
# 12230  मम पृष्ठगतौ तौ च चन्द्रसूर्याविवोदितौत्वत्सकाश...  ...  3.285714
# 12231  अरिघ्नं सिंहसङ्काशं क्षिप्रं द्रक्ष्यसि राघवम्...  ...  3.000000
# 12232  नखदंष्ट्रायुधान् वीरान् सिंहशार्दूलविक्रमान्वा...  ...  3.000000
# 12233  निवृत्तवनवासं च त्वया सार्धमरिन्दमम्अभिषिक्तमय...  ...  3.714286
# 12234  ततो मया वाग्भिरदीनभाषिणा शिवाभिरिष्टाभिरभिप्रस...  ...  5.400000
#
# [12235 rows x 5 columns]

# %%
l['dif'].mean()
# Out:
# 3.2638329945378546

# %%
j=-1
for i in l.dif :
  j+=1
  if(i>3.5):
    l=l.drop(j,axis=0)

    

l=l.reset_index(drop=True)

# %%
l
# Out:
#                                                    sans  ...       dif
# 0     कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  ...  2.375000
# 1     एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे महर्षे...  ...  1.909091
# 2     श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच श...  ...  3.125000
# 3     बहवो दुर्लभाश्चैव ये त्वया कीर्तिता गुणा मुने ...  ...  1.900000
# 4     बुद्धिमान्नीतिमान्वाग्मी श्रीमान् शत्रुनिबर्हण...  ...  3.428571
# ...                                                 ...  ...       ...
# 8407  अहं तावदिह प्राप्तः किं पुनस्ते महाबलाःन हि प्...  ...  2.166667
# 8408  तदलं परितापेन देवि मन्युर्व्यपैतु तेएकोत्पातेन...  ...  3.125000
# 8409  मम पृष्ठगतौ तौ च चन्द्रसूर्याविवोदितौत्वत्सकाश...  ...  3.285714
# 8410  अरिघ्नं सिंहसङ्काशं क्षिप्रं द्रक्ष्यसि राघवम्...  ...  3.000000
# 8411  नखदंष्ट्रायुधान् वीरान् सिंहशार्दूलविक्रमान्वा...  ...  3.000000
#
# [8412 rows x 5 columns]

# %%
l['dif'].mean()
# Out:
# 2.5094547505020626

# %%
l=l.drop(["sans_len","eng_len","dif"],axis=1)
l.head()
# Out:
#                                                 sans                                                eng
# 0  कोन्वस्मिन्साम्प्रतं लोके गुणवान्कश्च वीर्यवान...  who in this world lives today endowed with exc...
# 1  एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे महर्षे...  o maharshi i intend to hear about such a man w...
# 2  श्रुत्वा चैतत्ित्रलोकज्ञो वाल्मीकेर्नारदो वच श...  invited by valmiki to take his seat narada kno...
# 3  बहवो दुर्लभाश्चैव ये त्वया कीर्तिता गुणा मुने ...  o sage rare indeed are men endowed with the ma...
# 4  बुद्धिमान्नीतिमान्वाग्मी श्रीमान् शत्रुनिबर्हण...  he sri rama is a great intellectual adherent t...

# %%
df.to_csv('valmiki_ramayan_origanal1.txt', header=False, index=False, sep=',', mode='a',encoding='utf-8')
from google.colab import files
files.download('valmiki_ramayan_origanal1.txt')

# %%
l.to_csv('valmiki_ramayan_processed.txt', header=False, index=False, sep='\t', mode='a')
from google.colab import files
files.download('valmiki_ramayan_processed.txt')

# %%
df.describe()
# Out:
#          sans    eng
# count   12235  12235
# unique  12219  12024
# top
# freq        3    184

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12235 entries, 0 to 12234
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sans    12235 non-null  object
#  1   eng     12235 non-null  object
# dtypes: object(2)
# memory usage: 191.3+ KB

# %%
df.iloc[0,0].split()
# Out:
# ['कोन्वस्मिन्साम्प्रतं',
#  'लोके',
#  'गुणवान्कश्च',
#  'वीर्यवान्',
#  '।धर्मज्ञश्च',
#  'कृतज्ञश्च',
#  'सत्यवाक्यो',
#  'दृढव्रत:।।1.1.2।।']

# %%
all_hindi_words=[]
for hin in df.sans:
    for word in hin.split():
        if word not in all_hindi_words:
            all_hindi_words.append(word)
all_hindi_words
# Out:
# ['कोन्वस्मिन्साम्प्रतं',
#  'लोके',
#  'गुणवान्कश्च',
#  'वीर्यवान्',
#  '।धर्मज्ञश्च',
#  'कृतज्ञश्च',
#  'सत्यवाक्यो',
#  'दृढव्रत:।।1.1.2।।',
#  'चारित्रेण',
#  'च',
#  'को',
#  'युक्तस्सर्वभूतेषु',
#  'हित:',
#  '।विद्वान्क:',
#  'कस्समर्थश्च',
#  'कश्चैकप्रियदर्शन:',
#  '।।1.1.3।।',
#  'आत्मवान्को',
#  'जितक्रोधो',
#  'द्युतिमान्कोऽनसूयक:',
#  '।कस्य',
#  'बिभ्यति',
#  'देवाश्च',
#  'जातरोषस्य',
#  'संयुगे',
#  '।।1.1.4।।',
#  'एतदिच्छाम्यहं',
#  'श्रोतुं',
#  'परं',
#  'कौतूहलं',
#  'हि',
#  'मे',
#  '।महर्षे',
#  'त्वं',
#  'समर्थोऽसि',
#  'ज्ञातुमेवंविधं',
#  'नरम्',
#  '।।1.1.5।।',
#  'श्रुत्वा',
#  'चैतत्ित्रलोकज्ञो',
#  'वाल्मीकेर्नारदो',
#  'वच:',
#  '।श्रूयतामिति',
#  'चामन्त्त्र्य',
#  'प्रहृष्टो',
#  'वाक्यमब्रवीत्',
#  '।।1.1.6।।',
#  'बहवो',
#  'दुर्लभाश्चैव',
#  'ये',
#  'त्वया',
#  'कीर्तिता',
#  'गुणा:',
#  '।मुने',
#  'वक्ष्याम्यहं',
#  'बुद्ध्वा',
#  'तैर्युक्तश्श्रूयतान्नर:',
#  '।।1.1.7।।',
#  'इक्ष्वाकुवंशप्रभवो',
#  'रामो',
#  'नाम',
#  'जनैश्श्रुत:',
# ...

# %%
k=pd.DataFrame(all_hindi_words,columns=["word"])
k
# Out:
#                                   word
# 0                 कोन्वस्मिन्साम्प्रतं
# 1                                 लोके
# 2                          गुणवान्कश्च
# 3                            वीर्यवान्
# 4                          ।धर्मज्ञश्च
# ...                                ...
# 58191                राघवम्।।5.68.28।।
# 58192                 वाग्भिरदीनभाषिणा
# 58193  शिवाभिरिष्टाभिरभिप्रसादिता।जगाम
# 58194                      मैथिलात्मजा
# 58195           तदाभिपीडिता।।5.68.29।।
#
# [58196 rows x 1 columns]

# %%
def text_preprocessing2(lines):
  lines=lines.apply(lambda x: x.lower())
  lines=lines.apply(lambda x: re.sub("'", '', x))
  exclude = set(string.punctuation) # Set of all special characters
  lines=lines.apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
  remove_digits = str.maketrans('', '', digits)
  lines=lines.apply(lambda x: x.translate(remove_digits))
  lines = lines.apply(lambda x: re.sub("[२३०८१५७९४६।]", "", x))
  lines=lines.apply(lambda x: x.strip())
  lines=lines.apply(lambda x: re.sub(" +", " ", x))
  return lines

# %%
k.word=text_preprocessing2(k.word)
k
# Out:
#                                  word
# 0                कोन्वस्मिन्साम्प्रतं
# 1                                लोके
# 2                         गुणवान्कश्च
# 3                           वीर्यवान्
# 4                          धर्मज्ञश्च
# ...                               ...
# 58191                          राघवम्
# 58192                वाग्भिरदीनभाषिणा
# 58193  शिवाभिरिष्टाभिरभिप्रसादिताजगाम
# 58194                     मैथिलात्मजा
# 58195                     तदाभिपीडिता
#
# [58196 rows x 1 columns]

# %%
asd=[]
for hin in k.word:
    for word in hin.split():
      for j in word.split():
        if j not in asd:
            asd.append(j)
asd
# Out:
# ['कोन्वस्मिन्साम्प्रतं',
#  'लोके',
#  'गुणवान्कश्च',
#  'वीर्यवान्',
#  'धर्मज्ञश्च',
#  'कृतज्ञश्च',
#  'सत्यवाक्यो',
#  'दृढव्रत',
#  'चारित्रेण',
#  'च',
#  'को',
#  'युक्तस्सर्वभूतेषु',
#  'हित',
#  'विद्वान्क',
#  'कस्समर्थश्च',
#  'कश्चैकप्रियदर्शन',
#  'आत्मवान्को',
#  'जितक्रोधो',
#  'द्युतिमान्कोऽनसूयक',
#  'कस्य',
#  'बिभ्यति',
#  'देवाश्च',
#  'जातरोषस्य',
#  'संयुगे',
#  'एतदिच्छाम्यहं',
#  'श्रोतुं',
#  'परं',
#  'कौतूहलं',
#  'हि',
#  'मे',
#  'महर्षे',
#  'त्वं',
#  'समर्थोऽसि',
#  'ज्ञातुमेवंविधं',
#  'नरम्',
#  'श्रुत्वा',
#  'चैतत्ित्रलोकज्ञो',
#  'वाल्मीकेर्नारदो',
#  'वच',
#  'श्रूयतामिति',
#  'चामन्त्त्र्य',
#  'प्रहृष्टो',
#  'वाक्यमब्रवीत्',
#  'बहवो',
#  'दुर्लभाश्चैव',
#  'ये',
#  'त्वया',
#  'कीर्तिता',
#  'गुणा',
#  'मुने',
#  'वक्ष्याम्यहं',
#  'बुद्ध्वा',
#  'तैर्युक्तश्श्रूयतान्नर',
#  'इक्ष्वाकुवंशप्रभवो',
#  'रामो',
#  'नाम',
#  'जनैश्श्रुत',
#  'नियतात्मा',
#  'महावीर्यो',
#  'द्युतिमान्धृतिमान्',
#  'वशी',
#  'बुद्धिमान्नीतिमान्वाग्मी',
# ...

# %%
k.iloc[0,0].split()
# Out:
# ['कोन्वस्मिन्साम्प्रतं']

# %%
len_list_word=[]
for l in k.word:
    len_list_word.append(len(l.split(' ')))
max_length_scr = np.max(len_list_word)
max_length_scr
# Out:
# 1

# %%
all_hindi_words2=[]
for hin in df.eng:
    for word in hin.split():
        if word not in all_hindi_words2:
            all_hindi_words2.append(word)
all_hindi_words2
# Out:
# ['"Who',
#  'in',
#  'this',
#  'world',
#  'lives',
#  'today',
#  'endowed',
#  'with',
#  'excellent',
#  'qualities,',
#  'prowess,',
#  'righteousness,',
#  'gratitude,',
#  'truthfulness',
#  'and',
#  'firmness',
#  'his',
#  'vows?',
#  'Who',
#  'is',
#  'that',
#  'one',
#  'gifted',
#  'good',
#  'conduct,',
#  'given',
#  'to',
#  'the',
#  'wellbeing',
#  'of',
#  'all',
#  'living',
#  'creatures,',
#  'learned',
#  'lore',
#  '(knowledge',
#  'things',
#  'known),',
#  'capable',
#  'doing',
#  'which',
#  'others',
#  'can',
#  'not',
#  'do',
#  'singularly',
#  'handsome?',
#  '(among',
#  'men)',
#  'selfrestrained?',
#  'has',
#  'conquered',
#  'anger?',
#  'brilliance',
#  'free',
#  'from',
#  'envy?',
#  'when',
#  'excited',
#  'wrath',
#  'even',
#  'devatas,',
#  'are',
#  'afraid',
#  '(let',
#  'alone',
#  'foes)?',
#  'O',
#  'Maharshi,',
#  'I',
#  'intend',
#  'hear',
#  'about',
#  'such',
#  'a',
#  'man',
#  'whom',
#  'you',
#  'able',
# ...

# %%
m=pd.DataFrame(all_hindi_words2,columns=["word"])
m
# Out:
#                     word
# 0                   "Who
# 1                     in
# 2                   this
# 3                  world
# 4                  lives
# ...                  ...
# 26159          monkeys?,
# 26160           juniors.
# 26161         sorrowing.
# 26162          accountof
# 26163  quiet"৷৷इत्यार्षे
#
# [26164 rows x 1 columns]

# %%
len_list_word=[]
fgh=[]
len_w=[]
alphabet_string = string.ascii_lowercase
alphabet_list = list(alphabet_string)
alphabet_list.append("")
for i in alphabet_list:
    for l in m.word:
      fgh=l
      if(fgh[0]==i):
        len_list_word.append(l)
      else:
        if l not in len_w:
            len_w.append(l) 
         
    
len_list_word
# Out:
# ['and',
#  'all',
#  'anger?',
#  'are',
#  'afraid',
#  'alone',
#  'about',
#  'a',
#  'able',
#  'ascertained',
#  'as',
#  'adherent',
#  'armed',
#  'arms,',
#  'at',
#  'accessible',
#  'accomplished',
#  'archer).',
#  'an',
#  'all.',
#  'always',
#  'appearance.',
#  'appearance,',
#  'allconsuming',
#  'anger,',
#  'affectionate',
#  'approached',
#  'along',
#  'another',
#  'away,',
#  'against',
#  'addressing',
#  'alive,',
#  'although',
#  'accept',
#  'accordance',
#  'authority',
#  'again',
#  'awaiting',
#  'arrive',
#  'arrows,',
#  'ascetics',
#  'asuras',
#  'ascetics,',
#  'army',
#  'assuming',
#  'any',
#  'anger',
#  'away',
#  'abducted',
#  'ascetic',
#  'austerities.',
#  'advice',
#  'abduction',
#  'also',
#  'account',
#  'action',
#  'arrived',
#  'arch',
#  'allowed',
#  'achieving',
#  'agitated',
#  'anger)',
#  'appeared',
#  'accepting',
#  'assembly.',
#  'adored',
#  'animate',
#  'after',
#  'accompanied',
#  'arrived,',
#  'agonies,',
# ...

# %%
fgh=pd.DataFrame(len_list_word,columns=['words'])
fgh
# Out:
#          words
# 0          and
# 1          all
# 2       anger?
# 3          are
# 4       afraid
# ...        ...
# 20416  zigzag,
# 20417     zeal
# 20418  zealous
# 20419    zones
# 20420    zeal,
#
# [20421 rows x 1 columns]

# %%
fgh2=pd.DataFrame(len_w,columns=['words'])
fgh2
# Out:
#               words
# 0              "Who
# 1                in
# 2              this
# 3             world
# 4             lives
# ...             ...
# 26159  auspicious.'
# 26160        appeal
# 26161    assistants
# 26162     accomplsh
# 26163     accountof
#
# [26164 rows x 1 columns]

# %%
kjl=[]
for i in len_w:
  if i not in len_list_word:
    kjl.append(i)
kjl
# Out:
# ['"Who',
#  'Who',
#  '(knowledge',
#  '(among',
#  '(let',
#  'O',
#  'Maharshi,',
#  'I',
#  'Indeed',
#  'Invited',
#  'Valmiki',
#  'Narada,',
#  '"Listen',
#  'And',
#  '"O',
#  'Listen',
#  'People',
#  'Rama,',
#  'Ikshvaku,having',
#  'He',
#  '(Sri',
#  'Rama)',
#  '(sins),',
#  'Possessing',
#  '(sins).',
#  'Mighty',
#  'Pious,',
#  '(or',
#  '(on',
#  'Auspicious',
#  'Brahma,',
#  'Sri',
#  'Rama',
#  'Vedas',
#  '(he',
#  '(possessing',
#  '(and',
#  '(even',
#  '(in',
#  'Kausalya,',
#  'Himavant',
#  'Visnu',
#  'Moon',
#  'Kubera',
#  'Sun',
#  'With',
#  'Dasaratha',
#  '(apparent)',
#  'Thereafter,',
#  'Kaikeyi',
#  'Bharata.',
#  'Dasaratha,',
#  'Kaikeyi.',
#  'Lakshmana',
#  'Endowed',
#  'Sumitra.',
#  'Displaying',
#  'Born',
#  'Janaka',
#  'Sita,',
#  'Rohini,',
#  'Moon.',
#  'The',
#  'Guha,',
#  'Shrungiberapura',
#  'Sumantra',
#  'Sita',
#  'Ganga.',
#  'Moving',
#  'Chitrakuta',
#  'Bharadwaja.',
#  'They',
#  'When',
#  'Chitrakuta,',
#  'After',
# ...

# %%
kjlh=pd.DataFrame(kjl,columns=["word"])

# %%
kjlh
# Out:
#               word
# 0             "Who
# 1              Who
# 2       (knowledge
# 3           (among
# 4             (let
# ...            ...
# 5738  (Brahmastra)
# 5739    Despondent
# 5740         'Make
# 5741    (abruptly)
# 5742      'Mighty,
#
# [5743 rows x 1 columns]
